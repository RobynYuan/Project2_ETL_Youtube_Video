# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file_US_videos= "Resources/USvideos.csv"
USvideos = pd.read_csv(csv_file_US_videos)
USvideos.columns

US_videos_cleaned=USvideos[['video_id', 'trending_date','title','category_id','channel_title','publish_time','views', 'likes', 'dislikes', 'comment_count','description']]

US_videos_cleaned.drop_duplicates(subset ="video_id",
                     keep = 'last', inplace = True)
US_videos_cleaned
# Out:
# /Users/yuanzhong/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#           video_id trending_date  \
# 10     9wRQljFNDW8      17.14.11
# 36     Om_zGhJLZ5U      17.14.11
# 41     goP4Z5wyOlM      17.14.11
# 55     8NHA23f7LvU      17.14.11
# 76     IE-xepGLVt8      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  category_id  \
# 10     Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...           17
# 36        TL;DW - Every DCEU Movie Before Justice League            1
# 41     Iraq-Iran earthquake: Deadly tremor hits borde...           25
# 55     Jason Momoa Wows Hugh Grant With Some Dothraki...           24
# 76     Mayo Clinic's first face transplant patient me...           28
# ...                                                  ...          ...
# 40944                       The Cat Who Caught the Laser           15
# 40945                         True Facts : Ant Mutualism           22
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...           24
# 40947                How Black Panther Should Have Ended            1
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...           20
#
#                   channel_title              publish_time     views   likes  \
# 10                          NFL  2017-11-13T02:05:26.000Z     81377     655
# 36               Screen Junkies  2017-11-12T18:00:03.000Z    288922    7515
# 41                     BBC News  2017-11-12T21:16:40.000Z     34785     308
# 55       The Graham Norton Show  2017-11-10T19:06:23.000Z   1496225   16116
# 76                  Mayo Clinic  2017-11-10T12:04:17.000Z    237307    1896
# ...                         ...                       ...       ...     ...
# 40944             AaronsAnimals  2018-05-18T13:00:04.000Z   1685609   38160
# 40945                  zefrank1  2018-05-18T01:00:06.000Z   1064798   60008
# 40946                Brad Mondo  2018-05-18T17:34:22.000Z   1066451   48068
# 40947  How It Should Have Ended  2018-05-17T17:00:04.000Z   5660813  192957
# 40948              Call of Duty  2018-05-17T17:09:38.000Z  10306119  357079
#
#        dislikes  comment_count  \
# 10           25            177
# 36          792           2111
# 41           26            413
# 55          236            605
# 76           74            260
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                              description
# 10     New England Patriots returner Dion Lewis blast...
# 36     With Justice League approaching fast we rewatc...
# 41     A strong 7.2-magnitude earthquake has rattled ...
# 55     I think Sarah Millican was very excited for th...
# 76     One and a half years after the surgery that tr...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [6351 rows x 11 columns]

# %%
json_file = "Resources/US_category_id.json"
US_category_id = pd.read_json(json_file)

Item_id=US_category_id["items"]
new_Item_id=pd.json_normalize(Item_id)
Categories=new_Item_id [['id', 'snippet.title']]
Categories.rename(columns={"id": "category_id", "snippet.title": "categoryName"}, inplace = True)

Categories


# category=new_Item_id('id','snippet.title')
# Out:
# /Users/yuanzhong/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    category_id           categoryName
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# 24          37                 Family
# 25          38                Foreign
# 26          39                 Horror
# 27          40         Sci-Fi/Fantasy
# 28          41               Thriller
# 29          42                 Shorts
# 30          43                  Shows
# 31          44               Trailers

# %%
Categories['category_id'] = Categories['category_id'].astype(int)
us_youtube_df = pd.merge(US_videos_cleaned, Categories, on=['category_id'])
us_youtube_df
# Out:
# /var/folders/_p/18b2hw693fl_t0ch0jzbghqw0000gn/T/ipykernel_11000/3109214715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Categories['category_id'] = Categories['category_id'].astype(int)
#          video_id trending_date  \
# 0     9wRQljFNDW8      17.14.11
# 1     fIQ2Ty2OL34      17.14.11
# 2     agKDPntMv-E      17.14.11
# 3     Xl38SuxyrgM      17.14.11
# 4     0zk2SwmCpss      17.15.11
# ...           ...           ...
# 6346  pwGbwYAfSmg      18.04.06
# 6347  lM0yu7c6lQk      18.02.01
# 6348  Q1CFfU2gXHw      18.30.01
# 6349  7_FJUSBFbJM      18.29.04
# 6350  V6ElE2xs48c      18.06.06
#
#                                                   title  category_id  \
# 0     Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...           17
# 1     James Harden Triple-Double 2017.11.09 vs Cavs ...           17
# 2     Stephen A. Smith slams the Philadelphia 76ers ...           17
# 3     STEPH CURRY and OMRI CASSPI, postgame GSW (9-3...           17
# 4     Joel Embiid Full Highlights 2017.11.13 at Clip...           17
# ...                                                 ...          ...
# 6346                  5 books worth reading this summer           29
# 6347  You're not crazy. Apple is slowing down older ...           43
# 6348  Apple HomePod: Everything to know before you b...           43
# 6349  Game of Zones - Game of Zones - S5:E1: 'A Gold...           43
# 6350       Game of Zones - S5:E5: The Isle of Van Gundy           43
#
#         channel_title              publish_time    views  likes  dislikes  \
# 0                 NFL  2017-11-13T02:05:26.000Z    81377    655        25
# 1         FreeDawkins  2017-11-10T04:00:52.000Z    18573    420        10
# 2                ESPN  2017-11-08T15:59:06.000Z   470191   4037       430
# 3      LetsGoWarriors  2017-11-09T07:27:32.000Z    16305    147        13
# 4         FreeDawkins  2017-11-14T06:24:27.000Z    63780    831        12
# ...               ...                       ...      ...    ...       ...
# 6346       Bill Gates  2018-05-21T13:30:33.000Z   333587  10918       161
# 6347             CNET  2017-12-22T01:16:16.000Z   179723   4763       247
# 6348             CNET  2018-01-24T20:08:16.000Z    72607   1130       113
# 6349  Bleacher Report  2018-04-12T21:00:12.000Z  1445949  33261       475
# 6350  Bleacher Report  2018-05-10T21:01:22.000Z  1351321  22587       616
#
#       comment_count                                        description  \
# 0               177  New England Patriots returner Dion Lewis blast...
# 1               236  --Take your ball handling to the next level wi...
# 2              1553  First Take's Stephen A. Smith slams the Philad...
# 3                47  Previous video: Draymond postgame https://yout...
# 4               301  --Take your ball handling to the next level wi...
# ...             ...                                                ...
# 6346            613  If you’re looking for something to read over t...
# 6347           1998  Apple comes clean after overwhelming evidence ...
# 6348            264  We'll break down all the new Apple HomePod det...
# 6349           2174  In the season 5 premiere of Game of Zones, the...
# 6350           1649  On an island full of Van Gundys, Stan gets tal...
#
#                categoryName
# 0                    Sports
# 1                    Sports
# 2                    Sports
# 3                    Sports
# 4                    Sports
# ...                     ...
# 6346  Nonprofits & Activism
# 6347                  Shows
# 6348                  Shows
# 6349                  Shows
# 6350                  Shows
#
# [6351 rows x 12 columns]

# %%
final_table=us_youtube_df.drop(['description'], axis = 1)
final_table
# Out:
#          video_id trending_date  \
# 0     9wRQljFNDW8      17.14.11
# 1     fIQ2Ty2OL34      17.14.11
# 2     agKDPntMv-E      17.14.11
# 3     Xl38SuxyrgM      17.14.11
# 4     0zk2SwmCpss      17.15.11
# ...           ...           ...
# 6346  pwGbwYAfSmg      18.04.06
# 6347  lM0yu7c6lQk      18.02.01
# 6348  Q1CFfU2gXHw      18.30.01
# 6349  7_FJUSBFbJM      18.29.04
# 6350  V6ElE2xs48c      18.06.06
#
#                                                   title  category_id  \
# 0     Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...           17
# 1     James Harden Triple-Double 2017.11.09 vs Cavs ...           17
# 2     Stephen A. Smith slams the Philadelphia 76ers ...           17
# 3     STEPH CURRY and OMRI CASSPI, postgame GSW (9-3...           17
# 4     Joel Embiid Full Highlights 2017.11.13 at Clip...           17
# ...                                                 ...          ...
# 6346                  5 books worth reading this summer           29
# 6347  You're not crazy. Apple is slowing down older ...           43
# 6348  Apple HomePod: Everything to know before you b...           43
# 6349  Game of Zones - Game of Zones - S5:E1: 'A Gold...           43
# 6350       Game of Zones - S5:E5: The Isle of Van Gundy           43
#
#         channel_title              publish_time    views  likes  dislikes  \
# 0                 NFL  2017-11-13T02:05:26.000Z    81377    655        25
# 1         FreeDawkins  2017-11-10T04:00:52.000Z    18573    420        10
# 2                ESPN  2017-11-08T15:59:06.000Z   470191   4037       430
# 3      LetsGoWarriors  2017-11-09T07:27:32.000Z    16305    147        13
# 4         FreeDawkins  2017-11-14T06:24:27.000Z    63780    831        12
# ...               ...                       ...      ...    ...       ...
# 6346       Bill Gates  2018-05-21T13:30:33.000Z   333587  10918       161
# 6347             CNET  2017-12-22T01:16:16.000Z   179723   4763       247
# 6348             CNET  2018-01-24T20:08:16.000Z    72607   1130       113
# 6349  Bleacher Report  2018-04-12T21:00:12.000Z  1445949  33261       475
# 6350  Bleacher Report  2018-05-10T21:01:22.000Z  1351321  22587       616
#
#       comment_count           categoryName
# 0               177                 Sports
# 1               236                 Sports
# 2              1553                 Sports
# 3                47                 Sports
# 4               301                 Sports
# ...             ...                    ...
# 6346            613  Nonprofits & Activism
# 6347           1998                  Shows
# 6348            264                  Shows
# 6349           2174                  Shows
# 6350           1649                  Shows
#
# [6351 rows x 11 columns]

# %%
rds_connection_string = "postgres:motheR511037@localhost:5432/youtube_video"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# /var/folders/_p/18b2hw693fl_t0ch0jzbghqw0000gn/T/ipykernel_11000/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['Videos']

# %%
final_table.to_sql(name='Videos', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from public."Videos"', con=engine).head()
# Out:
#       video_id trending_date  \
# 0  9wRQljFNDW8      17.14.11
# 1  fIQ2Ty2OL34      17.14.11
# 2  agKDPntMv-E      17.14.11
# 3  Xl38SuxyrgM      17.14.11
# 4  0zk2SwmCpss      17.15.11
#
#                                                title  category_id  \
# 0  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...           17
# 1  James Harden Triple-Double 2017.11.09 vs Cavs ...           17
# 2  Stephen A. Smith slams the Philadelphia 76ers ...           17
# 3  STEPH CURRY and OMRI CASSPI, postgame GSW (9-3...           17
# 4  Joel Embiid Full Highlights 2017.11.13 at Clip...           17
#
#     channel_title              publish_time   views  likes  dislikes  \
# 0             NFL  2017-11-13T02:05:26.000Z   81377    655        25
# 1     FreeDawkins  2017-11-10T04:00:52.000Z   18573    420        10
# 2            ESPN  2017-11-08T15:59:06.000Z  470191   4037       430
# 3  LetsGoWarriors  2017-11-09T07:27:32.000Z   16305    147        13
# 4     FreeDawkins  2017-11-14T06:24:27.000Z   63780    831        12
#
#    comment_count categoryName
# 0            177       Sports
# 1            236       Sports
# 2           1553       Sports
# 3             47       Sports
# 4            301       Sports
